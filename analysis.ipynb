# %%
import pandas as pd

# %%
# !unzip csv/Monthly_count.zip
# Out:
# Archive:  csv/Monthly_count.zip
#   inflating: Pedestrian_Counting_System_-_Monthly__counts_per_hour_.csv

# %%
# !unzip csv/Sensor_location.zip
# Out:
# Archive:  csv/Sensor_location.zip
#   inflating: Pedestrian_Counting_System_-_Sensor_Locations.csv

# %%
location_info = pd.read_csv('csv/Pedestrian_Counting_System_-_Monthly__counts_per_hour_.csv')
location_sensor_info = pd.read_csv('csv/Pedestrian_Counting_System_-_Sensor_Locations.csv')

# %%
location_info
# Out:
#               ID                      Date_Time  Year     Month  Mdate  \
# 0        2887628  November 01, 2019 05:00:00 PM  2019  November      1
# 1        2887629  November 01, 2019 05:00:00 PM  2019  November      1
# 2        2887630  November 01, 2019 05:00:00 PM  2019  November      1
# 3        2887631  November 01, 2019 05:00:00 PM  2019  November      1
# 4        2887632  November 01, 2019 05:00:00 PM  2019  November      1
# ...          ...                            ...   ...       ...    ...
# 4367450  4372922      June 30, 2022 07:00:00 PM  2022      June     30
# 4367451  4372923      June 30, 2022 08:00:00 PM  2022      June     30
# 4367452  4372924      June 30, 2022 09:00:00 PM  2022      June     30
# 4367453  4372925      June 30, 2022 10:00:00 PM  2022      June     30
# 4367454  4372926      June 30, 2022 11:00:00 PM  2022      June     30
#
#               Day  Time  Sensor_ID                        Sensor_Name  \
# 0          Friday    17         34               Flinders St-Spark La
# 1          Friday    17         39                       Alfred Place
# 2          Friday    17         37                    Lygon St (East)
# 3          Friday    17         40       Lonsdale St-Spring St (West)
# 4          Friday    17         36                    Queen St (West)
# ...           ...   ...        ...                                ...
# 4367450  Thursday    19         86  Queensberry St - Errol St (South)
# 4367451  Thursday    20         86  Queensberry St - Errol St (South)
# 4367452  Thursday    21         86  Queensberry St - Errol St (South)
# 4367453  Thursday    22         86  Queensberry St - Errol St (South)
# 4367454  Thursday    23         86  Queensberry St - Errol St (South)
#
#          Hourly_Counts
# 0                  300
# 1                  604
# 2                  216
# 3                  627
# 4                  774
# ...                ...
# 4367450             92
# 4367451             80
# 4367452             32
# 4367453             33
# 4367454             18
#
# [4367455 rows x 10 columns]

# %%
location_sensor_info
# Out:
#     sensor_id                sensor_description sensor_name installation_date  \
# 0          57                  Bourke St Bridge    BouBri_T        2018/08/13
# 1          32                       City Square       CSq_T        2013/12/20
# 2          68  Flinders Ln -Degraves St (North)    FLDegN_T        2020/06/03
# 3          40      Lonsdale St-Spring St (West)    Spr201_T        2015/01/19
# 4           1        Bourke Street Mall (North)    Bou292_T        2009/03/24
# ..        ...                               ...         ...               ...
# 81         75     Spring St- Flinders st (West)    SprFli_T        2020/12/18
# 82         87                       23 Errol St   Errol23_T        2022/05/20
# 83         72                 Flinders St- ACMI      ACMI_T        2020/11/30
# 84         79               Flinders St (South)     FliSS_T        2021/09/10
# 85         85               Macaulay Rd (North)    488Mac_T        2021/12/21
#
#    status                                  note direction_1 direction_2  \
# 0       A                                   NaN        East        West
# 1       R  Device has been removed (24/01/2017)         NaN         NaN
# 2       A                                   NaN        East        West
# 3       A                                   NaN       South       North
# 4       A                                   NaN        East        West
# ..    ...                                   ...         ...         ...
# 81      A                                   NaN       South       North
# 82      A                                   NaN       South       North
# 83      A                                   NaN        East        West
# 84      A                                   NaN        East        West
# 85      A                                   NaN        East        West
#
#      latitude   longitude                      location
# 0  -37.817660  144.950262  (-37.81766034, 144.95026189)
# 1  -37.815724  144.966863  (-37.81572426, 144.96686315)
# 2  -37.816835  144.965604  (-37.81683473, 144.96560387)
# 3  -37.809980  144.972282  (-37.80998025, 144.97228184)
# 4  -37.813481  144.965159  (-37.81348124, 144.96515921)
# ..        ...         ...                           ...
# 81 -37.815140  144.974683  (-37.81513959, 144.97468257)
# 82 -37.804536  144.949225   (-37.80453633, 144.9492246)
# 83 -37.817250  144.968734  (-37.81725021, 144.96873406)
# 84 -37.817927  144.966173   (-37.8179273, 144.96617276)
# 85 -37.794311  144.929740  (-37.79431098, 144.92973978)
#
# [86 rows x 11 columns]

# %%
location_info[location_info.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [ID, Date_Time, Year, Month, Mdate, Day, Time, Sensor_ID, Sensor_Name, Hourly_Counts]
# Index: []

# %%
location_info[location_info['ID'].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [ID, Date_Time, Year, Month, Mdate, Day, Time, Sensor_ID, Sensor_Name, Hourly_Counts]
# Index: []

# %%
location_sensor_info[location_sensor_info.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [sensor_id, sensor_description, sensor_name, installation_date, status, note, direction_1, direction_2, latitude, longitude, location]
# Index: []

# %%
daily_count = location_info.groupby(['Day','Sensor_ID','Sensor_Name'],as_index=False).agg({'Hourly_Counts': 'sum'}).sort_values(by='Day',ascending=False)

# %%
day_list = daily_count.Day.unique()

# %%
for day in day_list:
    print(daily_count[daily_count.Day==day].sort_values(by='Hourly_Counts',ascending=False).head(10))
# Out:
#            Day  Sensor_ID                        Sensor_Name  Hourly_Counts
# 561  Wednesday          4                   Town Hall (West)       20360823
# 563  Wednesday          6  Flinders Street Station Underpass       19002309
# 560  Wednesday          3                  Melbourne Central       16657083
# 562  Wednesday          5                     Princes Bridge       15592856
# 559  Wednesday          2         Bourke Street Mall (South)       15343311
# 558  Wednesday          1         Bourke Street Mall (North)       15043324
# 581  Wednesday         24      Spencer St-Collins St (North)       12922557
# 579  Wednesday         22    Flinders St-Elizabeth St (East)       12031778
# 572  Wednesday         15                      State Library       11000867
# 570  Wednesday         13                  Flagstaff Station       10553562
#          Day  Sensor_ID                        Sensor_Name  Hourly_Counts
# 468  Tuesday          4                   Town Hall (West)       19457168
# 470  Tuesday          6  Flinders Street Station Underpass       18461430
# 467  Tuesday          3                  Melbourne Central       16073224
# 466  Tuesday          2         Bourke Street Mall (South)       14429616
# 469  Tuesday          5                     Princes Bridge       14396109
# 465  Tuesday          1         Bourke Street Mall (North)       14273069
# 488  Tuesday         24      Spencer St-Collins St (North)       12543187
# 486  Tuesday         22    Flinders St-Elizabeth St (East)       11864474
# 479  Tuesday         15                      State Library       10617852
# 477  Tuesday         13                  Flagstaff Station       10430342
#           Day  Sensor_ID                        Sensor_Name  Hourly_Counts
# 375  Thursday          4                   Town Hall (West)       21187600
# 377  Thursday          6  Flinders Street Station Underpass       19413550
# 374  Thursday          3                  Melbourne Central       17019854
# 373  Thursday          2         Bourke Street Mall (South)       16322770
# 372  Thursday          1         Bourke Street Mall (North)       15965870
# 376  Thursday          5                     Princes Bridge       15704870
# 395  Thursday         24      Spencer St-Collins St (North)       12928593
# 393  Thursday         22    Flinders St-Elizabeth St (East)       12088848
# 386  Thursday         15                      State Library       11091657
# 384  Thursday         13                  Flagstaff Station       10454900
#         Day  Sensor_ID                        Sensor_Name  Hourly_Counts
# 282  Sunday          4                   Town Hall (West)       18172940
# 281  Sunday          3                  Melbourne Central       15544124
# 283  Sunday          5                     Princes Bridge       15480437
# 279  Sunday          1         Bourke Street Mall (North)       13626411
# 280  Sunday          2         Bourke Street Mall (South)       13405435
# 284  Sunday          6  Flinders Street Station Underpass       12931378
# 300  Sunday         22    Flinders St-Elizabeth St (East)        9225154
# 313  Sunday         35                          Southbank        9037869
# 293  Sunday         15                      State Library        8931922
# 306  Sunday         28                    The Arts Centre        8853109
#           Day  Sensor_ID                        Sensor_Name  Hourly_Counts
# 189  Saturday          4                   Town Hall (West)       22499236
# 188  Saturday          3                  Melbourne Central       19012837
# 190  Saturday          5                     Princes Bridge       18233579
# 187  Saturday          2         Bourke Street Mall (South)       17003142
# 186  Saturday          1         Bourke Street Mall (North)       16748863
# 191  Saturday          6  Flinders Street Station Underpass       15314200
# 220  Saturday         35                          Southbank       10878637
# 200  Saturday         15                      State Library       10673040
# 207  Saturday         22    Flinders St-Elizabeth St (East)       10583641
# 213  Saturday         28                    The Arts Centre        9753895
#         Day  Sensor_ID                        Sensor_Name  Hourly_Counts
# 96   Monday          4                   Town Hall (West)       19272251
# 98   Monday          6  Flinders Street Station Underpass       17752947
# 95   Monday          3                  Melbourne Central       15577022
# 94   Monday          2         Bourke Street Mall (South)       14689966
# 97   Monday          5                     Princes Bridge       14521729
# 93   Monday          1         Bourke Street Mall (North)       14218144
# 116  Monday         24      Spencer St-Collins St (North)       11777417
# 114  Monday         22    Flinders St-Elizabeth St (East)       11537518
# 107  Monday         15                      State Library       10339353
# 105  Monday         13                  Flagstaff Station        9654896
#        Day  Sensor_ID                        Sensor_Name  Hourly_Counts
# 3   Friday          4                   Town Hall (West)       24393876
# 5   Friday          6  Flinders Street Station Underpass       21211433
# 2   Friday          3                  Melbourne Central       19853833
# 1   Friday          2         Bourke Street Mall (South)       18800045
# 4   Friday          5                     Princes Bridge       18367835
# 0   Friday          1         Bourke Street Mall (North)       18348011
# 23  Friday         24      Spencer St-Collins St (North)       12951080
# 21  Friday         22    Flinders St-Elizabeth St (East)       12619633
# 14  Friday         15                      State Library       12265360
# 34  Friday         35                          Southbank       10917020

# %%
df1[df1.Day=='Monday'].sort_values(by='Hourly_Counts',ascending=False).head(10)
# Out:
#         Day  Sensor_ID                        Sensor_Name  Hourly_Counts
# 96   Monday          4                   Town Hall (West)       19272251
# 98   Monday          6  Flinders Street Station Underpass       17752947
# 95   Monday          3                  Melbourne Central       15577022
# 94   Monday          2         Bourke Street Mall (South)       14689966
# 97   Monday          5                     Princes Bridge       14521729
# 93   Monday          1         Bourke Street Mall (North)       14218144
# 116  Monday         24      Spencer St-Collins St (North)       11777417
# 114  Monday         22    Flinders St-Elizabeth St (East)       11537518
# 107  Monday         15                      State Library       10339353
# 105  Monday         13                  Flagstaff Station        9654896

# %%
df1[df1.Day=='Tuesday'].sort_values(by='Hourly_Counts',ascending=False).head(10)
# Out:
#          Day  Sensor_ID                        Sensor_Name  Hourly_Counts
# 468  Tuesday          4                   Town Hall (West)       19457168
# 470  Tuesday          6  Flinders Street Station Underpass       18461430
# 467  Tuesday          3                  Melbourne Central       16073224
# 466  Tuesday          2         Bourke Street Mall (South)       14429616
# 469  Tuesday          5                     Princes Bridge       14396109
# 465  Tuesday          1         Bourke Street Mall (North)       14273069
# 488  Tuesday         24      Spencer St-Collins St (North)       12543187
# 486  Tuesday         22    Flinders St-Elizabeth St (East)       11864474
# 479  Tuesday         15                      State Library       10617852
# 477  Tuesday         13                  Flagstaff Station       10430342

# %%
df1[df1.Day=='Wednesday'].sort_values(by='Hourly_Counts',ascending=False).head(10)
# Out:
#            Day  Sensor_ID                        Sensor_Name  Hourly_Counts
# 561  Wednesday          4                   Town Hall (West)       20360823
# 563  Wednesday          6  Flinders Street Station Underpass       19002309
# 560  Wednesday          3                  Melbourne Central       16657083
# 562  Wednesday          5                     Princes Bridge       15592856
# 559  Wednesday          2         Bourke Street Mall (South)       15343311
# 558  Wednesday          1         Bourke Street Mall (North)       15043324
# 581  Wednesday         24      Spencer St-Collins St (North)       12922557
# 579  Wednesday         22    Flinders St-Elizabeth St (East)       12031778
# 572  Wednesday         15                      State Library       11000867
# 570  Wednesday         13                  Flagstaff Station       10553562

# %%
df1[df1.Day=='Thursday'].sort_values(by='Hourly_Counts',ascending=False).head(10)
# Out:
#           Day  Sensor_ID                        Sensor_Name  Hourly_Counts
# 375  Thursday          4                   Town Hall (West)       21187600
# 377  Thursday          6  Flinders Street Station Underpass       19413550
# 374  Thursday          3                  Melbourne Central       17019854
# 373  Thursday          2         Bourke Street Mall (South)       16322770
# 372  Thursday          1         Bourke Street Mall (North)       15965870
# 376  Thursday          5                     Princes Bridge       15704870
# 395  Thursday         24      Spencer St-Collins St (North)       12928593
# 393  Thursday         22    Flinders St-Elizabeth St (East)       12088848
# 386  Thursday         15                      State Library       11091657
# 384  Thursday         13                  Flagstaff Station       10454900

# %%
df1[df1.Day=='Friday'].sort_values(by='Hourly_Counts',ascending=False).head(10)
# Out:
#        Day  Sensor_ID                        Sensor_Name  Hourly_Counts
# 3   Friday          4                   Town Hall (West)       24393876
# 5   Friday          6  Flinders Street Station Underpass       21211433
# 2   Friday          3                  Melbourne Central       19853833
# 1   Friday          2         Bourke Street Mall (South)       18800045
# 4   Friday          5                     Princes Bridge       18367835
# 0   Friday          1         Bourke Street Mall (North)       18348011
# 23  Friday         24      Spencer St-Collins St (North)       12951080
# 21  Friday         22    Flinders St-Elizabeth St (East)       12619633
# 14  Friday         15                      State Library       12265360
# 34  Friday         35                          Southbank       10917020

# %%
df1[df1.Day=='Saturday'].sort_values(by='Hourly_Counts',ascending=False).head(10)
# Out:
#           Day  Sensor_ID                        Sensor_Name  Hourly_Counts
# 189  Saturday          4                   Town Hall (West)       22499236
# 188  Saturday          3                  Melbourne Central       19012837
# 190  Saturday          5                     Princes Bridge       18233579
# 187  Saturday          2         Bourke Street Mall (South)       17003142
# 186  Saturday          1         Bourke Street Mall (North)       16748863
# 191  Saturday          6  Flinders Street Station Underpass       15314200
# 220  Saturday         35                          Southbank       10878637
# 200  Saturday         15                      State Library       10673040
# 207  Saturday         22    Flinders St-Elizabeth St (East)       10583641
# 213  Saturday         28                    The Arts Centre        9753895

# %%
df1[df1.Day=='Sunday'].sort_values(by='Hourly_Counts',ascending=False).head(10)
# Out:
#         Day  Sensor_ID                        Sensor_Name  Hourly_Counts
# 282  Sunday          4                   Town Hall (West)       18172940
# 281  Sunday          3                  Melbourne Central       15544124
# 283  Sunday          5                     Princes Bridge       15480437
# 279  Sunday          1         Bourke Street Mall (North)       13626411
# 280  Sunday          2         Bourke Street Mall (South)       13405435
# 284  Sunday          6  Flinders Street Station Underpass       12931378
# 300  Sunday         22    Flinders St-Elizabeth St (East)        9225154
# 313  Sunday         35                          Southbank        9037869
# 293  Sunday         15                      State Library        8931922
# 306  Sunday         28                    The Arts Centre        8853109

# %%
merge_pandas = location_info.merge(location_sensor_info, how='inner', left_on='Sensor_ID', right_on='sensor_id')

# %%
merge_pandas
# Out:
#               ID                      Date_Time  Year     Month  Mdate  \
# 0        2887628  November 01, 2019 05:00:00 PM  2019  November      1
# 1        2887683  November 01, 2019 06:00:00 PM  2019  November      1
# 2        2887738  November 01, 2019 07:00:00 PM  2019  November      1
# 3        2887793  November 01, 2019 08:00:00 PM  2019  November      1
# 4        2887848  November 01, 2019 09:00:00 PM  2019  November      1
# ...          ...                            ...   ...       ...    ...
# 4367450  4372922      June 30, 2022 07:00:00 PM  2022      June     30
# 4367451  4372923      June 30, 2022 08:00:00 PM  2022      June     30
# 4367452  4372924      June 30, 2022 09:00:00 PM  2022      June     30
# 4367453  4372925      June 30, 2022 10:00:00 PM  2022      June     30
# 4367454  4372926      June 30, 2022 11:00:00 PM  2022      June     30
#
#               Day  Time  Sensor_ID                        Sensor_Name  \
# 0          Friday    17         34               Flinders St-Spark La
# 1          Friday    18         34               Flinders St-Spark La
# 2          Friday    19         34               Flinders St-Spark La
# 3          Friday    20         34               Flinders St-Spark La
# 4          Friday    21         34               Flinders St-Spark La
# ...           ...   ...        ...                                ...
# 4367450  Thursday    19         86  Queensberry St - Errol St (South)
# 4367451  Thursday    20         86  Queensberry St - Errol St (South)
# 4367452  Thursday    21         86  Queensberry St - Errol St (South)
# 4367453  Thursday    22         86  Queensberry St - Errol St (South)
# 4367454  Thursday    23         86  Queensberry St - Errol St (South)
#
#          Hourly_Counts  ...                 sensor_description sensor_name  \
# 0                  300  ...               Flinders St-Spark La     Fli32_T
# 1                  240  ...               Flinders St-Spark La     Fli32_T
# 2                  158  ...               Flinders St-Spark La     Fli32_T
# 3                  118  ...               Flinders St-Spark La     Fli32_T
# 4                  131  ...               Flinders St-Spark La     Fli32_T
# ...                ...  ...                                ...         ...
# 4367450             92  ...  Queensberry St - Errol St (South)    574Qub_T
# 4367451             80  ...  Queensberry St - Errol St (South)    574Qub_T
# 4367452             32  ...  Queensberry St - Errol St (South)    574Qub_T
# 4367453             33  ...  Queensberry St - Errol St (South)    574Qub_T
# 4367454             18  ...  Queensberry St - Errol St (South)    574Qub_T
#
#         installation_date status note direction_1 direction_2   latitude  \
# 0              2014/06/08      R  NaN        East        West -37.815367
# 1              2014/06/08      R  NaN        East        West -37.815367
# 2              2014/06/08      R  NaN        East        West -37.815367
# 3              2014/06/08      R  NaN        East        West -37.815367
# 4              2014/06/08      R  NaN        East        West -37.815367
# ...                   ...    ...  ...         ...         ...        ...
# 4367450        2021/12/21      A  NaN        East        West -37.803087
# 4367451        2021/12/21      A  NaN        East        West -37.803087
# 4367452        2021/12/21      A  NaN        East        West -37.803087
# 4367453        2021/12/21      A  NaN        East        West -37.803087
# 4367454        2021/12/21      A  NaN        East        West -37.803087
#
#           longitude                      location
# 0        144.974156  (-37.81536669, 144.97415645)
# 1        144.974156  (-37.81536669, 144.97415645)
# 2        144.974156  (-37.81536669, 144.97415645)
# 3        144.974156  (-37.81536669, 144.97415645)
# 4        144.974156  (-37.81536669, 144.97415645)
# ...             ...                           ...
# 4367450  144.949087  (-37.80308676, 144.94908661)
# 4367451  144.949087  (-37.80308676, 144.94908661)
# 4367452  144.949087  (-37.80308676, 144.94908661)
# 4367453  144.949087  (-37.80308676, 144.94908661)
# 4367454  144.949087  (-37.80308676, 144.94908661)
#
# [4367455 rows x 21 columns]

# %%
merge_pandas['Sensor_Name'].equals(merge_pandas['sensor_description'])
# Out:
# False

# %%
unmatched_pd = merge_pandas.loc[~(merge_pandas['Sensor_Name'] == merge_pandas['sensor_description'])]

# %%
unmatched_pd.to_csv('check_sensor_unmatch.csv')

# %%
monthly_count= location_info.groupby(['Month','Sensor_ID','Sensor_Name'],as_index=False).agg({'Hourly_Counts': 'sum'}).sort_values(by='Month',ascending=False)

# %%
month_list=monthly_count.Month.unique()

# %%
for month in month_list:
    print(monthly_count[monthly_count.Month==month].sort_values(by='Hourly_Counts',ascending=False).head(10))
# Out:
#          Month  Sensor_ID                        Sensor_Name  Hourly_Counts
# 936  September          4                   Town Hall (West)       11475209
# 935  September          3                  Melbourne Central        9902555
# 938  September          6  Flinders Street Station Underpass        9602620
# 934  September          2         Bourke Street Mall (South)        8286561
# 933  September          1         Bourke Street Mall (North)        8192967
# 937  September          5                     Princes Bridge        7823066
# 954  September         22    Flinders St-Elizabeth St (East)        6435942
# 947  September         15                      State Library        6321620
# 956  September         24      Spencer St-Collins St (North)        6126071
# 960  September         28                    The Arts Centre        4742644
#        Month  Sensor_ID                        Sensor_Name  Hourly_Counts
# 858  October          4                   Town Hall (West)       11152763
# 860  October          6  Flinders Street Station Underpass       10333881
# 855  October          1         Bourke Street Mall (North)        8737215
# 856  October          2         Bourke Street Mall (South)        8675275
# 857  October          3                  Melbourne Central        8260476
# 859  October          5                     Princes Bridge        7877358
# 869  October         15                      State Library        6942115
# 878  October         24      Spencer St-Collins St (North)        6728313
# 876  October         22    Flinders St-Elizabeth St (East)        5860962
# 889  October         35                          Southbank        5276274
#         Month  Sensor_ID                        Sensor_Name  Hourly_Counts
# 780  November          4                   Town Hall (West)       12136661
# 782  November          6  Flinders Street Station Underpass       10598560
# 778  November          2         Bourke Street Mall (South)        9772438
# 779  November          3                  Melbourne Central        9752026
# 781  November          5                     Princes Bridge        8942629
# 777  November          1         Bourke Street Mall (North)        8871745
# 798  November         22    Flinders St-Elizabeth St (East)        7197048
# 800  November         24      Spencer St-Collins St (North)        6661345
# 791  November         15                      State Library        6630549
# 811  November         35                          Southbank        5660775
#     Month  Sensor_ID                        Sensor_Name  Hourly_Counts
# 689   May          4                   Town Hall (West)       11591495
# 691   May          6  Flinders Street Station Underpass       10787077
# 688   May          3                  Melbourne Central       10615667
# 686   May          1         Bourke Street Mall (North)        9774547
# 690   May          5                     Princes Bridge        9561337
# 687   May          2         Bourke Street Mall (South)        8901477
# 707   May         22    Flinders St-Elizabeth St (East)        7592610
# 700   May         15                      State Library        6580684
# 709   May         24      Spencer St-Collins St (North)        6009446
# 720   May         35                          Southbank        5862252
#      Month  Sensor_ID                        Sensor_Name  Hourly_Counts
# 600  March          4                   Town Hall (West)       12655259
# 599  March          3                  Melbourne Central       11737486
# 602  March          6  Flinders Street Station Underpass       11419121
# 601  March          5                     Princes Bridge       11001403
# 597  March          1         Bourke Street Mall (North)        9643824
# 598  March          2         Bourke Street Mall (South)        9017586
# 618  March         22    Flinders St-Elizabeth St (East)        7566831
# 620  March         24      Spencer St-Collins St (North)        7149300
# 611  March         15                      State Library        7091544
# 631  March         35                          Southbank        5930487
#     Month  Sensor_ID                        Sensor_Name  Hourly_Counts
# 510  June          4                   Town Hall (West)       11934368
# 509  June          3                  Melbourne Central       10287904
# 512  June          6  Flinders Street Station Underpass        9867379
# 507  June          1         Bourke Street Mall (North)        9455301
# 511  June          5                     Princes Bridge        8997795
# 508  June          2         Bourke Street Mall (South)        8818621
# 528  June         22    Flinders St-Elizabeth St (East)        6549459
# 530  June         24      Spencer St-Collins St (North)        6139724
# 521  June         15                      State Library        5463552
# 541  June         35                          Southbank        5242526
#     Month  Sensor_ID                        Sensor_Name  Hourly_Counts
# 432  July          4                   Town Hall (West)       12555809
# 431  July          3                  Melbourne Central       10445330
# 434  July          6  Flinders Street Station Underpass       10203582
# 429  July          1         Bourke Street Mall (North)        9103779
# 430  July          2         Bourke Street Mall (South)        9048971
# 433  July          5                     Princes Bridge        8531264
# 443  July         15                      State Library        6434716
# 452  July         24      Spencer St-Collins St (North)        6016559
# 450  July         22    Flinders St-Elizabeth St (East)        5883997
# 463  July         35                          Southbank        4994974
#        Month  Sensor_ID                        Sensor_Name  Hourly_Counts
# 344  January          4                   Town Hall (West)       11967639
# 345  January          5                     Princes Bridge       10796073
# 346  January          6  Flinders Street Station Underpass       10279628
# 342  January          2         Bourke Street Mall (South)        9106886
# 343  January          3                  Melbourne Central        8433264
# 341  January          1         Bourke Street Mall (North)        8136291
# 362  January         22    Flinders St-Elizabeth St (East)        6307184
# 375  January         35                          Southbank        6279974
# 368  January         28                    The Arts Centre        6214671
# 364  January         24      Spencer St-Collins St (North)        6096117
#         Month  Sensor_ID                        Sensor_Name  Hourly_Counts
# 255  February          4                   Town Hall (West)       11156945
# 257  February          6  Flinders Street Station Underpass       10292516
# 256  February          5                     Princes Bridge        9493960
# 254  February          3                  Melbourne Central        9004266
# 252  February          1         Bourke Street Mall (North)        8335328
# 253  February          2         Bourke Street Mall (South)        8134134
# 275  February         24      Spencer St-Collins St (North)        6591467
# 273  February         22    Flinders St-Elizabeth St (East)        6547085
# 266  February         15                      State Library        5708978
# 279  February         28                    The Arts Centre        5657723
#         Month  Sensor_ID                        Sensor_Name  Hourly_Counts
# 171  December          4                   Town Hall (West)       14578191
# 169  December          2         Bourke Street Mall (South)       13134233
# 173  December          6  Flinders Street Station Underpass       11352132
# 172  December          5                     Princes Bridge       10750919
# 168  December          1         Bourke Street Mall (North)       10478082
# 170  December          3                  Melbourne Central        9958892
# 189  December         22    Flinders St-Elizabeth St (East)        7643186
# 202  December         35                          Southbank        7087552
# 182  December         15                      State Library        6079839
# 191  December         24      Spencer St-Collins St (North)        5946613
#       Month  Sensor_ID                        Sensor_Name  Hourly_Counts
# 93   August          4                   Town Hall (West)       11675587
# 92   August          3                  Melbourne Central       10477135
# 95   August          6  Flinders Street Station Underpass        9214815
# 90   August          1         Bourke Street Mall (North)        8299742
# 91   August          2         Bourke Street Mall (South)        8282631
# 94   August          5                     Princes Bridge        7861189
# 104  August         15                      State Library        6404288
# 113  August         24      Spencer St-Collins St (North)        5933432
# 111  August         22    Flinders St-Elizabeth St (East)        4805402
# 102  August         13                  Flagstaff Station        4648096
#     Month  Sensor_ID                        Sensor_Name  Hourly_Counts
# 3   April          4                   Town Hall (West)       12463968
# 2   April          3                  Melbourne Central       10862976
# 4   April          5                     Princes Bridge       10660422
# 5   April          6  Flinders Street Station Underpass       10135936
# 0   April          1         Bourke Street Mall (North)        9194871
# 1   April          2         Bourke Street Mall (South)        8815472
# 21  April         22    Flinders St-Elizabeth St (East)        7561340
# 23  April         24      Spencer St-Collins St (North)        6215026
# 14  April         15                      State Library        6159571
# 27  April         28                    The Arts Centre        6090009

# %%
monthly_count[monthly_count.Month=='January'].sort_values(by='Hourly_Counts',ascending=False).head(10)
# Out:
#        Month  Sensor_ID                        Sensor_Name  Hourly_Counts
# 344  January          4                   Town Hall (West)       11967639
# 345  January          5                     Princes Bridge       10796073
# 346  January          6  Flinders Street Station Underpass       10279628
# 342  January          2         Bourke Street Mall (South)        9106886
# 343  January          3                  Melbourne Central        8433264
# 341  January          1         Bourke Street Mall (North)        8136291
# 362  January         22    Flinders St-Elizabeth St (East)        6307184
# 375  January         35                          Southbank        6279974
# 368  January         28                    The Arts Centre        6214671
# 364  January         24      Spencer St-Collins St (North)        6096117

# %%
monthly_count[monthly_count.Month=='January'].sort_values(by='Hourly_Counts',ascending=False).head(10)
